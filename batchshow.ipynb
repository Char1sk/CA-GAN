# %%
from PIL import Image
import matplotlib.pyplot as plt
import random

# %%
# img = Image.open('./Output/0Pure/150/1.jpg')
# plt.subplot(1, 2, 1)
# plt.imshow(img)
# plt.subplot(1, 2, 2)
# plt.imshow(img)


with open('./data/list_test_cufs.txt') as f:
    lines = [l.split('||')[1] for l in f.readlines()]
# print(lines)

idx = random.randint(1, 338)

plt.subplots(1, 8, figsize=(15, 2))
for i in range(1, 8):
    img = Image.open(f'./Output/0Pure/{100*i}/{idx}.jpg')
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])

print({lines[idx-1]})
img = Image.open(f'{lines[idx-1]}')
plt.subplot(1, 8, 8)
plt.imshow(img)
plt.xticks([])
plt.yticks([])

plt.show()
# Out:
# {'../Datasets/CUFS/CUHK/photos/186.jpg'}
